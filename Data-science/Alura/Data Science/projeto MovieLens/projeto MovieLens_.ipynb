# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
'notas = pd.read_csv("ratings.csv")
'filmes = pd.read_csv("movies.csv")
'notas.columns = ["usuarios","filmeid","notas","momentos"]
'filmes.columns = ["filmeid","titulo","Genero"]
'''
print(notas.head())
print(filmes.head())
print(notas['notas'].mean())
print(notas['notas'].median())
print(notas.notas.describe())
print(notas.shape)
print(notas['notas'].unique())
print(notas['notas'].value_counts())
notas.notas.plot(kind='hist')
notas.notas.describe()
sns.boxplot(notas.notas)
notas.query('filmeid==1').notas.median()
notas.groupby("filmeid").notas.median()
media_notas.plot(kind='hist') O plot exibi um grafico, quando colocamos kind = hist exibimos um historiograma, q é nesse caso 
saber quantas medias mais teve por filme. tipo quantos filmes receberam media 4.

sns.boxplot(media_notas)
sns.distplot(media_notas,bins=10) o bins é pra saber quantas barras vao ter

plt.hist(media_notas) é a biblioteca que tanto o pandas como o seaborn usam para os graficos.
plt.figure(figsize=(5,8)) determina o tamanho do grafico
'''
# Out:
#   File "<ipython-input-4-a6d83d2f7415>", line 4
#     'notas = pd.read_csv("ratings.csv")
#                                        ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Nova seção

# %% [markdown]
# # Nova seção

# %% [markdown]
# # Nova seção

# %%
media_notas = notas.groupby("filmeid").notas.median()
plt.figure(figsize=(5,8))

plt.hist(media_notas)
# Out:
# (array([ 111.,  199.,  283.,  801.,  687., 2076., 1940., 2614.,  655.,
#          358.]),
#  array([0.5 , 0.95, 1.4 , 1.85, 2.3 , 2.75, 3.2 , 3.65, 4.1 , 4.55, 5.  ]),
#  <a list of 10 Patch objects>)

# %%
# Out:
# count    9724.000000
# mean        3.292112
# std         0.897683
# min         0.500000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000
# Name: notas, dtype: float64
