# %%
import pandas as pd
import tabula
from tables import Column

# %%
#dfs = tabula.read_pdf("tabela.pdf",  stream = True ,pages = 'all') #nesse modo com o stream ligado a organização pega o primeiro item da pagina como coluna. para esse caso não é algo bom
dfs = tabula.read_pdf("C:/Users/gabri/Documents/python/Data-science/Alura/Python Pandas/tabela.pdf",  pages = 'all')
#len(dfs)
#for itens in dfs:
#  print(itens)
#dfs.index = range(dfs.shape[0])

tamanho = len(dfs)
df2 = pd.DataFrame(dfs[0])
i=1
for i in range(tamanho): 
  df = pd.DataFrame(dfs[i])
  df.columns = dfs[0].columns
  df2 = pd.merge(df2, df,how = 'outer')
  df2.sort_values(by = 'Infinitive',inplace = True)
  df2.sort_index(inplace = True, axis = 1)
df2[['Infinitive','Significado']]

pd.get_option('display.max_rows')
pd.set_option('display.max_rows',202)
df2
# Out:
#     Infinitive        Past       Significado
# 0      Abandon   Abandoned         Abandonar
# 1      Abolish   Abolished            Abolir
# 2       Absorb    Absorbed          Absorver
# 3        Abuse      Abused            Abusar
# 4       Accede     Acceded           Acessar
# 5       Accent    Accented          Acentuar
# 6       Accuse     Accused            Acusar
# 7      Acquire    Acquired          Adquirir
# 8          Act       Acted        Agir/atuar
# 9          Add       Added         Adicionar
# 10     Address   Addressed        Dirigir-se
# 11      Admire     Admired           Admirar
# 12       Admit    Admitted           Admitir
# 13       Adore      Adored            Adorar
# 14     Advance    Advanced           Avançar
# 15   Advertise  Advertised          Anunciar
# 16      Advice     Adviced        Aconselhar
# 17       Agree      Agreed         Concordar
# 18       Allow     Allowed          Permitir
# 19       Amuse      Amused          Divertir
# 20    Announce   Announced          Anunciar
# 21       Annoy     Annoyed         Incomodar
# 22      Answer    Answered         Responder
# 23   Apologize  Apologized      Desculpar-se
# 24      Appear    Appeared          Aparecer
# 25    Approach  Approached      Aproximar-se
# 26     Arrange    Arranged         Organizar
# 27      Arrest    Arrested           Prender
# 28      Arrive     Arrived            Chegar
# 29         Ask       Asked   Pedir/perguntar
# 30      Assist    Assisted            Ajudar
# 31      Assure     Assured         Assegurar
# 32      Attack    Attacked            Atacar
# 33     Attempt   Attempted            Tentar
# 34       Avoid     Avoided            Evitar
# 35     Balance    Balanced        Equilibrar
# 36         Beg      Begged          Implorar
# 37      Behave     Behaved      Comportar-se
# 38     Believe    Believed         Acreditar
# 39      Belong    Belonged         Pertencer
# 40       Blame      Blamed             Culpa
# 41       Bless     Blessed          Abençoar
# 42     Breathe    Breathed          Respirar
# 43       Brush     Brushed           Escovar
# 44        Call      Called            Chamar
# 45        Care       Cared            Cuidar
# 46       Carry     Carried          Carregar
# 47        Cash      Cashed            Cobrar
# 48      Change     Changed             Mudar
# 49      Charge     Charged            Cobrar
# 50       Check     Checked         Verificar
# 51       Claim     Claimed          Reclamar
# 52       Clean     Cleaned            Limpar
# 53       Climb     Climbed            Trepar
# 54       Close      Closed            Fechar
# 55     Collect   Collected           Coletar
# 56     Combine    Combined          Combinar
# 57     Command   Commanded           Ordenar
# 58      Commit   Committed           Cometer
# 59     Compare    Compared          Comparar
# 60    Complete   Completed         Completar
# 61     Compose    Composed            Compor
# 62    Consider  Considered        Considerar
# 63     Consist   Consisted         Consistir
# 64     Contain   Contained            Conter
# 65    Continue   Continued         Continuar
# 66        Cook      Cooked          Cozinhar
# 67        Copy      Copied            Copiar
# 68       Count     Counted            Contar
# 69       Cover     Covered            Cobrir
# 70       Crash     Crashed           Colidir
# 71       Cross     Crossed        Atravessar
# 72       Crown     Crowned            Coroar
# 73         Cry       Cried            Chorar
# 74       Dance      Danced            Dançar
# 75     Declare    Declared          Declarar
# 76       Delay     Delayed           Atrasar
# 77     Deliver   Delivered          Entregar
# 78        Deny      Denied             Negar
# 79     Destroy   Destroyed          Destruir
# 80      Devote     Devoted           Dedicar
# 81         Die        Died            Morrer
# 82       Dress     Dressed            Vestir
# 83        Drop     Dropped       Deixar cair
# 84         Dry       Dried             Secar
# 85      Engage     Engaged           Engajar
# 86       Enjoy     Enjoyed         Desfrutar
# 87        Envy      Envied           Invejar
# 88     Exclaim   Exclaimed          Exclamar
# 89     Explain   Explained          Explicar
# 90     Express   Expressed         Expressar
# 91        Fail      Failed            Falhar
# 92        File       Filed          Arquivar
# 93        Fill      Filled            Encher
# 94      Finish    Finished          Terminar
# 95        Fire       Fired  Disparar/demitir
# 96        Fish      Fished            Pescar
# 97         Fix       Fixed         Consertar
# 98      Follow    Followed            Seguir
# 99         Fry       Fried            Fritar
# 100       Gain      Gained            Ganhar
# 101      Guess     Guessed         Adivinhar
# 102     Happen    Happened         Acontecer
# 103       Help      Helped            Ajudar
# 104       Hope       Hoped           Esperar
# 105      Hurry     Hurried       Apressar-se
# 106    Imagine    Imagined          Imaginar
# 107      Judge      Judged            Julgar
# 108       Kill      Killed             Matar
# 109       Kiss      Kissed            Beijar
# 110      Laugh     Laughed               Rir
# 111       Like       Liked            Gostar
# 112       Look      Looked             Olhar
# 113   Maintain  Maintained            Manter
# 114     Manage     Managed             Gerir
# 115       Mark      Marked         Assinalar
# 116      Marry     Married             Casar
# 117    Massage    Massaged         Massagear
# 118    Measure    Measured             Medir
# 119       Miss      Missed             Errar
# 120       Move       Moved             Mover
# 121       Name       Named     Chamar/nomear
# 122       Note       Noted            Anotar
# 123     Notice      Notice             Notar
# 124     Number    Numbered           Numerar
# 125    Observe    Observed          Observar
# 126      Offer     Offered          Oferecer
# 127       Open      Opened             Abrir
# 128      Order     Ordered           Ordenar
# 129       Park      Parked        Estacionar
# 130       Pass      Passed            Passar
# 131    Perform   Performed       Desempenhar
# 132      Phone      Phoned         Telefonar
# 133       Pick      Picked            Colher
# 134       Plan     Planned          Planejar
# 135       Play      Played           Brincar
# 136     Please     Pleased           Agradar
# 137   Practice   Practiced          Praticar
# 138       Pray      Prayed             Rezar
# 139     Prefer    Prefered          Preferir
# 140    Prepare    Prepared          Preparar
# 141    Promise    Promised          Prometer
# 142  Pronounce  Pronounced        Pronunciar
# 143     Punish    Punished             Punir
# 144       Push      Pushed          Empurrar
# 145       Rain      Rained            Chover
# 146      Raise      Raised          Levantar
# 147    Receive    Received           Receber
# 148     Refuse     Refused           Recusar
# 149   Register  Registered         Inscrever
# 150   Remember  Remembered           Lembrar
# 151     Repair    Repaired         Consertar
# 152     Repeat    Repeated           Repetir
# 153     Report    Reported          Informar
# 154    Request   Requested             Pedir
# 155    Require    Required        Requisitar
# 156    Reserve    Reserved          Reservar
# 157    Resolve    Resolved          Resolver
# 158       Sail      Sailed           Navegar
# 159       Save       Saved            Salvar
# 160     Search    Searched          Procurar
# 161      Serve      Served            Servir
# 162       Sign      Signed           Assinar
# 163      Smile      Smiled            Sorrir
# 164      Smoke      Smoked            Fumaça
# 165      Sound     Sounded              Soar
# 166      Spell     spelled          Soletrar
# 167      Start     Started           Começar
# 168       Stay      Stayed             Ficar
# 169       Stop     Stopped             Parar
# 170      Study     Studied           Estudar
# 171     Suffer    Suffered            Sofrer
# 172   Surprise   Surprised       Surpreender
# 173       Talk      Talked             Falar
# 174      Taste      Tasted          Saborear
# 175       Test      Tested            Testar
# 176      Thank     Thanked         Agradecer
# 177        Tie        Tied           Amarrar
# 178      Touch     Touched             Tocar
# 179      Train     Trained           Treinar
# 180  Translate  Translated          Traduzir
# 181     Travel    Traveled            Viajar
# 182      Trust     Trusted           Confiar
# 183        Try       Tried            Tentar
# 184       Turn      Turned             Virar
# 185      Unite      United              Unir
# 186        Use        Used              Usar
# 187       Vary      Varied            Variar
# 188      Visit     Visited           Visitar
# 189       Wait      Waited           Esperar
# 190       Walk      Walked             Andar
# 191       Want      Wanted            Querer
# 192       Warm      Warmed           Aquecer
# 193       Wash      Washed             Lavar
# 194      Watch     Watched             Olhar
# 195      Water     Watered             Regar
# 196      Weigh     Weighed             Pesar
# 197    Whistle    Whistled          Assobiar
# 198       Wish      Wished           Desejar
# 199       Work      Worked         Trabalhar
# 200      Worry     Worried      Preocupar-se
# 201      Wound     Wounded             Ferir

# %% [markdown]
# #Verificar se tem valores nulos na tabela

# %%
df2['Significado'].isnull()# verica se tem algum valor em null e retorna true caso seja nulo o notnull retorna false caso tenha valores em null
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# 111    False
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# 158    False
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
# Name: Significado, dtype: bool
