# %%
import pandas as pd

# %% [markdown]
# # relatorio de analise

# %%
arquivo = pd.read_csv("C:/Users/gabri/Documents/python/Data-science//Alura/Python Pandas/aluguel.csv",sep=';')
dados = arquivo.Tipo.drop_duplicates()
residencial = ['Quitinete',
 'Casa',
 'Apartamento',
 'Casa de Condomínio',
 'Casa de Vila']
selecao = arquivo.Tipo.isin(residencial)
dados_Residencial = arquivo[selecao]
list(dados_Residencial.Tipo.drop_duplicates())
tamanho = dados_Residencial.shape[0]
dados_Residencial.index = range(tamanho)
type(arquivo)
# Out:
# pandas.core.frame.DataFrame

# %%
arquivo.shape[0]
# Out:
# 32960

# %%
import pandas as pd

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']
df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)
selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
letras2 = [chr(i + 65) for i in range(6)]
df.index = letras2
df
# Out:
#     N
# A   0
# B   2
# C   4
# D   6
# E   8
# F  10

# %% [markdown]
# ## Exportando Base de Dados'

# %%
dados_Residencial.to_csv('C:/Users/gabri/Documents/python/Data-science/Alura/Python Pandas/aluguel_Residencial.csv', sep = ';', index = False)

# %%
dados_Residencial2 =pd.read_csv('C:/Users/gabri/Documents/python/Data-science/Alura/Python Pandas/aluguel_Residencial.csv', sep = ';')
dados_Residencial2
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
dados_Residencial2.Tipo.drop_duplicates(inplace = True)

# %%
dados_Residencial2
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
selecao = (dados_Residencial2['Tipo'] =='Apartamento') & (dados_Residencial2['Bairro'] == 'Leblon')
n3 = dados_Residencial2[~selecao]
n3
# Out:
#                      Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0               Quitinete            Copacabana        1      0       0    40
# 1                    Casa       Jardim Botânico        2      0       1   100
# 2             Apartamento                Centro        1      0       0    15
# 3             Apartamento          Higienópolis        1      0       0    48
# 4             Apartamento          Vista Alegre        3      1       0    70
# ...                   ...                   ...      ...    ...     ...   ...
# 22574  Casa de Condomínio       Barra da Tijuca        5      3       4   450
# 22575         Apartamento                 Méier        2      0       0    70
# 22576           Quitinete                Centro        0      0       0    27
# 22577         Apartamento           Jacarepaguá        3      1       2    78
# 22578         Apartamento  São Francisco Xavier        2      1       0    48
#
# ...

# %%
dados = pd.DataFrame(dados_Residencial)
n1 = dados[selecao]
n1
# Out:
#               Tipo  Bairro  Quartos  Vagas  Suites  Area    Valor  Condominio  \
# 29     Apartamento  Leblon        3      1       0   110   3900.0      1500.0
# 62     Apartamento  Leblon        2      1       1    80   3500.0       990.0
# 94     Apartamento  Leblon        3      2       1   147   7500.0      1028.0
# 101    Apartamento  Leblon        3      1       0    85   3900.0       800.0
# 120    Apartamento  Leblon        4      4       4   380  40000.0      4700.0
# ...            ...     ...      ...    ...     ...   ...      ...         ...
# 22540  Apartamento  Leblon        3      2       1   200  16000.0      4200.0
# 22541  Apartamento  Leblon        4      3       2   280  10000.0      3315.0
# 22562  Apartamento  Leblon        1      1       1    50   4300.0      1730.0
# 22570  Apartamento  Leblon        3      0       1    80   3000.0      1010.0
# 22579  Apartamento  Leblon        2      0       0    70   3000.0       760.0
#
#          IPTU
# 29      120.0
# ...

# %%
selecao2 = n3['Bairro']=='Leblon'
n4 = n3[selecao2]
n4.index = range(n4.shape[0])
n4
# Out:
#                   Tipo  Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0            Quitinete  Leblon        1      0       0    30   1700.0
# 1            Quitinete  Leblon        1      0       0    25   1950.0
# 2            Quitinete  Leblon        1      0       1    32   2000.0
# 3   Casa de Condomínio  Leblon        5      0       5   850  30000.0
# 4   Casa de Condomínio  Leblon        4      4       4   653  15000.0
# 5   Casa de Condomínio  Leblon        5      0       5   900  30000.0
# 6            Quitinete  Leblon        1      0       0    30   1800.0
# 7   Casa de Condomínio  Leblon        4      3       4   600  15000.0
# 8            Quitinete  Leblon        1      0       0    30   1800.0
# 9   Casa de Condomínio  Leblon        6      2       2   350  18000.0
# 10           Quitinete  Leblon        0      0       0    50   2100.0
# 11           Quitinete  Leblon        1      0       0    50   1700.0
# ...

# %%
# Out:
#       Tipo Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio  IPTU
# 29     NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 62     NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 94     NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 101    NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 120    NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# ...    ...    ...      ...    ...     ...   ...    ...         ...   ...
# 22540  NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 22541  NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 22562  NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 22570  NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
# 22579  NaN    NaN      NaN    NaN     NaN   NaN    NaN         NaN   NaN
#
# [1277 rows x 9 columns]
